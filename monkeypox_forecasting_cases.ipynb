# %%
import numpy as np
import pandas as pd
import csv

# %%
# reading a tsv(tab separated values) file
file=pd.read_table("monkeypox_abstracts_dataset.tsv")
file.head()
# Out:
#    ArticleId                                              Title  \
# 0   30981594  Human Monkeypox: Epidemiologic and Clinical Ch...
# 1   34662033                                          Monkeypox
# 2   33167496  Monkeypox Virus in Nigeria: Infection Biology,...
# 3   24158414                                    Human monkeypox
# 4   30445121  Vaccinating against monkeypox in the Democrati...
#
#                                             Abstract          NumberCitations  \
# 0  Recently, concern has been raised about the em...                       10
# 1  Monkeypox virus was first isolated and identif...  Information Unavailable
# 2  Monkeypox is a zoonotic disease caused by monk...                        3
# 3  Human monkeypox is a zoonotic Orthopoxvirus wi...                       48
# 4  Healthcare-associated transmission of monkeypo...                        5
#
#   PublicationType                                           Keywords  \
# ...

# %%
file['Abstract'][0]
# Out:
# 'Recently, concern has been raised about the emergence of human monkeypox virus and the occasionally severe clinical presentation bearing resemblance to that of smallpox. In 2018 3 patients in the UK were diagnosed with monkeypox, and the frequency and geographic distribution of cases across West and Central Africa have increased in recent years. In Nigeria, most monkeypox patients are aged <40 years and lack cross-protective immunity because they were born after discontinuation of the smallpox eradication campaign. This article reviews the epidemiology, clinical features, and management of monkeypox and discusses its growing public health threat in this context.'

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ArticleId        728 non-null    int64
#  1   Title            728 non-null    object
#  2   Abstract         728 non-null    object
#  3   NumberCitations  728 non-null    object
#  4   PublicationType  728 non-null    object
#  5   Keywords         728 non-null    object
#  6   DOI              728 non-null    object
#  7   Authors          728 non-null    object
#  8   JournalCitation  728 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 51.3+ KB

# %%
df=pd.read_csv("monkeypox_df.csv")
df.head()
# Out:
#     ID     Status                             Location    City  Country  Age  \
# 0  1.0  confirmed  Guy's and St Thomas Hospital London  London  England  NaN
# 1  2.0  confirmed  Guy's and St Thomas Hospital London  London  England  NaN
# 2  3.0  confirmed                               London  London  England  NaN
# 3  4.0  confirmed                               London  London  England  NaN
# 4  5.0  confirmed                               London  London  England  NaN
#
#   Gender  Date_onset Date_confirmation        Symptoms  ...  \
# 0    NaN  2022-04-29        2022-05-06            rash  ...
# 1    NaN  2022-05-05        2022-05-12            rash  ...
# 2    NaN  2022-04-30        2022-05-13  vesicular rash  ...
# 3   Male         NaN        2022-05-15  vesicular rash  ...
# 4   Male         NaN        2022-05-15  vesicular rash  ...
#
#   Travel_history_country   Genomics_Metadata Confirmation_method  \
# 0                Nigeria  West African Clade              RT-PCR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3570 entries, 0 to 3569
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       3569 non-null   float64
#  1   Status                   3569 non-null   object
#  2   Location                 1846 non-null   object
#  3   City                     593 non-null    object
#  4   Country                  3569 non-null   object
#  5   Age                      928 non-null    object
#  6   Gender                   920 non-null    object
#  7   Date_onset               22 non-null     object
#  8   Date_confirmation        3157 non-null   object
#  9   Symptoms                 128 non-null    object
#  10  Hospitalised (Y/N/NA)    172 non-null    object
#  11  Date_hospitalisation     17 non-null     object
#  12  Isolated (Y/N/NA)        213 non-null    object
#  13  Date_isolation           14 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Status', 'Location', 'City', 'Country', 'Age', 'Gender',
#        'Date_onset', 'Date_confirmation', 'Symptoms', 'Hospitalised (Y/N/NA)',
#        'Date_hospitalisation', 'Isolated (Y/N/NA)', 'Date_isolation',
#        'Outcome', 'Contact_comment', 'Contact_ID', 'Contact_location',
#        'Travel_history (Y/N/NA)', 'Travel_history_entry',
#        'Travel_history_start', 'Travel_history_location',
#        'Travel_history_country', 'Genomics_Metadata', 'Confirmation_method',
#        'Source', 'Source_II', 'Date_entry', 'Date_last_modified', 'Source_III',
#        'Source_IV', 'Country_ISO3'],
#       dtype='object')

# %%
df['Genomics_Metadata'].unique()
# Out:
# array(['West African Clade', nan,
#        'https://www.ncbi.nlm.nih.gov/nuccore/ON563414',
#        'Genomic sequence',
#        'https://www.ncbi.nlm.nih.gov/nuccore/ON631963.1/',
#        'https://virological.org/t/first-german-genome-sequence-of-monkeypox-virus-associated-to-multi-country-outbreak-in-may-2022/812#post_1',
#        'https://www.argentina.gob.ar/noticias/salud-informa-que-el-resultado-de-la-muestra-pcr-tomada-por-anlis-malbran-al-primer-caso',
#        'West African clade',
#        'https://virological.org/t/illumina-whole-genome-sequence-of-monkeypox-virus-in-a-patient-travelling-from-the-canary-islands-to-france/829',
#        'https://virological.org/t/first-french-draft-genome-sequence-of-monkeypox-virus-may-2022/819#post_1',
#        'https://mpox-lapis.gen-spectrum.org/v1/sample/fasta?strain=mpx-37-Finland_consensus',
#        'https://virological.org/t/first-monkeypox-virus-genome-sequence-from-brazil/850'],
#       dtype=object)

# %%
df['Status'].unique()
# Out:
# array(['confirmed', 'discarded', 'suspected', nan], dtype=object)

# %%
df['Symptoms'].unique()
# Out:
# array(['rash', 'vesicular rash', 'skin lesions, ulcerative lesions',
#        'ulcerative lesions', nan, 'oral and genital ulcers, fever',
#        'lesions', 'perianal papules; inguinal adenopathy',
#        'genital ulcers', 'genital rash',
#        'Slight swallowing difficulties and an elevated temperature',
#        'fever, rash', 'skin rashes', 'fever, lesions', 'pustules, fever',
#        'skin lesions', 'fever, cough, skin lesions',
#        'fever, pustules on hands, body pains', 'blisters, high fever',
#        'genital ulcer lesions', 'muscle aches, fever, skin lesions',
#        'blisters', 'fever, skin lesions',
#        'erythema with vesicles and papules, difficulty breathing, headache, fever',
#        'skin lesions, spots on skin, severe anemia',
#        'skin lesions, headaches, enlarged lymph nodes, fever',
#        'fever, fatigue, headache, muscle pain',
#        'skin rashes, dysphagia, muscle pain, fever, decreased physical strength, enlarged lymph nodes',
# ...

# %%
df['Age'].unique()
# Out:
# array([nan, '20-44', '30-59', '40-44', '25-29', '20-59', '30-34', '20-64',
#        '40-49', '30-39', '50-59', '35-39', '15-74', '15-19', '<40',
#        '55-59', '45-49', '20-24', '30-50', '50-54', '10-14', '70-74',
#        '15-64', '60-64', '65-69', '25-49', '40-45', '26-54', '5-9',
#        '22-55', '30-54', '0-5', '30-49', '20-29', '40-42', '15-69',
#        '45-50', '35-40', '50-55', '20-69', '34-46'], dtype=object)

# %%
df['Age'].fillna('Unknown',inplace=True)

# %%
df['Age'].unique()
# Out:
# array(['Unknown', '20-44', '30-59', '40-44', '25-29', '20-59', '30-34',
#        '20-64', '40-49', '30-39', '50-59', '35-39', '15-74', '15-19',
#        '<40', '55-59', '45-49', '20-24', '30-50', '50-54', '10-14',
#        '70-74', '15-64', '60-64', '65-69', '25-49', '40-45', '26-54',
#        '5-9', '22-55', '30-54', '0-5', '30-49', '20-29', '40-42', '15-69',
#        '45-50', '35-40', '50-55', '20-69', '34-46'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Male', 'Female', 'CAN'], dtype=object)

# %%
df['Gender'].fillna("Unknown",inplace=True)

# %%
def symp_dict(row):
    symp_row=row
    symp_list=symp_row.split(",")
    if symp_row=="Unknown":
        score=0
    else:
        score=len(symp_list)
    return score

# %%
df['Symptoms'].fillna("Unknown",inplace=True)

# %%
df['Symp_count']=df['Symptoms'].apply(symp_dict)

# %%
df
# Out:
#           ID     Status                             Location    City  \
# 0        1.0  confirmed  Guy's and St Thomas Hospital London  London
# 1        2.0  confirmed  Guy's and St Thomas Hospital London  London
# 2        3.0  confirmed                               London  London
# 3        4.0  confirmed                               London  London
# 4        5.0  confirmed                               London  London
# ...      ...        ...                                  ...     ...
# 3565  3565.0  confirmed                                Texas     NaN
# 3566  3566.0  confirmed                                 Utah     NaN
# 3567  3567.0  confirmed                           Washington     NaN
# 3568  3568.0  confirmed                              Indiana     NaN
# 3569  3569.0  confirmed                             Maryland     NaN
#
#             Country      Age   Gender  Date_onset Date_confirmation  \
# 0           England  Unknown  Unknown  2022-04-29        2022-05-06
# ...

# %%
df['Symp_count'].unique()
# Out:
# array([1, 2, 0, 3, 4, 6, 5], dtype=int64)

# %%
#drop few columns 
df.drop(columns=['Source','Source_II','Source_III','Source_IV'],inplace=True)

# %%
df.head()
# Out:
#     ID     Status                             Location    City  Country  \
# 0  1.0  confirmed  Guy's and St Thomas Hospital London  London  England
# 1  2.0  confirmed  Guy's and St Thomas Hospital London  London  England
# 2  3.0  confirmed                               London  London  England
# 3  4.0  confirmed                               London  London  England
# 4  5.0  confirmed                               London  London  England
#
#        Age   Gender  Date_onset Date_confirmation        Symptoms  ...  \
# 0  Unknown  Unknown  2022-04-29        2022-05-06            rash  ...
# 1  Unknown  Unknown  2022-05-05        2022-05-12            rash  ...
# 2  Unknown  Unknown  2022-04-30        2022-05-13  vesicular rash  ...
# 3  Unknown     Male         NaN        2022-05-15  vesicular rash  ...
# 4  Unknown     Male         NaN        2022-05-15  vesicular rash  ...
#
#   Travel_history_entry Travel_history_start Travel_history_location  \
# ...

# %%
df.drop(columns='ID',inplace=True)

# %%
df['Status'].fillna('Unknown',inplace=True)

# %%
df['Status'].unique()
# Out:
# array(['confirmed', 'discarded', 'suspected', 'Unknown'], dtype=object)

# %%
df.loc[df['Status']=='confirmed','Status']='C'

# %%
df.loc[df['Status']=='discarded','Status']='D'
df.loc[df['Status']=='suspected','Status']='S'
df.loc[df['Status']=='Unknown','Status']='U'

# %%
df['Status'].unique()
# Out:
# array(['C', 'D', 'S', 'U'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3570 entries, 0 to 3569
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Status                   3570 non-null   object
#  1   Location                 1846 non-null   object
#  2   City                     593 non-null    object
#  3   Country                  3569 non-null   object
#  4   Age                      3570 non-null   object
#  5   Gender                   3570 non-null   object
#  6   Date_onset               22 non-null     object
#  7   Date_confirmation        3157 non-null   object
#  8   Symptoms                 3570 non-null   object
#  9   Hospitalised (Y/N/NA)    172 non-null    object
#  10  Date_hospitalisation     17 non-null     object
#  11  Isolated (Y/N/NA)        213 non-null    object
#  12  Date_isolation           14 non-null     object
#  13  Outcome                  1 non-null      object
# ...

# %%
df['Outcome'].unique()
# Out:
# array([nan, 'Recovered'], dtype=object)

# %%
df.columns
# Out:
# Index(['Status', 'Location', 'City', 'Country', 'Age', 'Gender', 'Date_onset',
#        'Date_confirmation', 'Symptoms', 'Hospitalised (Y/N/NA)',
#        'Date_hospitalisation', 'Isolated (Y/N/NA)', 'Date_isolation',
#        'Outcome', 'Contact_comment', 'Contact_ID', 'Contact_location',
#        'Travel_history (Y/N/NA)', 'Travel_history_entry',
#        'Travel_history_start', 'Travel_history_location',
#        'Travel_history_country', 'Genomics_Metadata', 'Confirmation_method',
#        'Date_entry', 'Date_last_modified', 'Country_ISO3', 'Symp_count'],
#       dtype='object')

# %%
df.Age.unique()
# Out:
# array(['Unknown', '20-44', '30-59', '40-44', '25-29', '20-59', '30-34',
#        '20-64', '40-49', '30-39', '50-59', '35-39', '15-74', '15-19',
#        '<40', '55-59', '45-49', '20-24', '30-50', '50-54', '10-14',
#        '70-74', '15-64', '60-64', '65-69', '25-49', '40-45', '26-54',
#        '5-9', '22-55', '30-54', '0-5', '30-49', '20-29', '40-42', '15-69',
#        '45-50', '35-40', '50-55', '20-69', '34-46'], dtype=object)

# %%
df.loc[df['Country']=='England','Age'].unique
# Out:
# <bound method Series.unique of 0       Unknown
# 1       Unknown
# 2       Unknown
# 3       Unknown
# 4       Unknown
#          ...
# 3348    Unknown
# 3349    Unknown
# 3350    Unknown
# 3351    Unknown
# 3352    Unknown
# Name: Age, Length: 766, dtype: object>

# %%
df['Symptoms'].unique()
# Out:
# array(['rash', 'vesicular rash', 'skin lesions, ulcerative lesions',
#        'ulcerative lesions', 'Unknown', 'oral and genital ulcers, fever',
#        'lesions', 'perianal papules; inguinal adenopathy',
#        'genital ulcers', 'genital rash',
#        'Slight swallowing difficulties and an elevated temperature',
#        'fever, rash', 'skin rashes', 'fever, lesions', 'pustules, fever',
#        'skin lesions', 'fever, cough, skin lesions',
#        'fever, pustules on hands, body pains', 'blisters, high fever',
#        'genital ulcer lesions', 'muscle aches, fever, skin lesions',
#        'blisters', 'fever, skin lesions',
#        'erythema with vesicles and papules, difficulty breathing, headache, fever',
#        'skin lesions, spots on skin, severe anemia',
#        'skin lesions, headaches, enlarged lymph nodes, fever',
#        'fever, fatigue, headache, muscle pain',
# ...

# %%
# which age group has the max symptoms and 
# most common symptoms and which age group
# under 18 
# middle age 
# above 60

#location basis max age grp
